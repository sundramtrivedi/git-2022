# %%
import pandas as pd

# %%
air_df = pd.read_csv("airlines.csv")

# %%
air_df
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 0       2003/06           6            June       2003
# ...

# %%
air_df.info() # Info of the table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
# ...

# %%
air_df.head() # by default print first 5 lines
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
air_df.head(30) # return 30 lines from top
# Out:
#    Airport.Code                                       Airport.Name Time.Label  \
# 0           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1           BOS                    Boston, MA: Logan International    2003/06
# 2           BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3           CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4           DCA  Washington, DC: Ronald Reagan Washington National    2003/06
# 5           DEN                   Denver, CO: Denver International    2003/06
# 6           DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...    2003/06
# 7           DTW            Detroit, MI: Detroit Metro Wayne County    2003/06
# 8           EWR           Newark, NJ: Newark Liberty International    2003/06
# 9           FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...    2003/06
# 10          IAD    Washington, DC: Washington Dulles International    2003/06
# ...

# %%
air_df.tail() # return lines from bottom
# Out:
#      Airport.Code                                      Airport.Name  \
# 4403          SAN            San Diego, CA: San Diego International
# 4404          SEA         Seattle, WA: Seattle/Tacoma International
# 4405          SFO    San Francisco, CA: San Francisco International
# 4406          SLC  Salt Lake City, UT: Salt Lake City International
# 4407          TPA                    Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 4403    2016/01           1         January       2016
# 4404    2016/01           1         January       2016
# 4405    2016/01           1         January       2016
# 4406    2016/01           1         January       2016
# 4407    2016/01           1         January       2016
#
#       Statistics.# of Delays.Carrier  Statistics.# of Delays.Late Aircraft  \
# 4403                             280                                   397
# ...

# %%
air_df.info
# Out:
# <bound method DataFrame.info of      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# ...

# %%
air_df.loc[2:2] # rows [start_row : end_row] # end row is not excluded
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 2           6            June       2003                             296
#
#    Statistics.# of Delays.Late Aircraft  \
# 2                                   477
#
#    Statistics.# of Delays.National Aviation System  \
# 2                                              389
#
#    Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 2                                8  ...                        1245
#
#   Statistics.Flights.Diverted  Statistics.Flights.On Time  \
# 2                          15                        6998
#
#    Statistics.Flights.Total  Statistics.Minutes Delayed.Carrier  \
# 2                      8287                               13635
#
#    Statistics.Minutes Delayed.Late Aircraft  \
# ...

# %%
air_df.iloc[2:2] # iloc fetch by index and loc fetch by index but the assigned
# Out:
# Empty DataFrame
# Columns: [Airport.Code, Airport.Name, Time.Label, Time.Month, Time.Month Name, Time.Year, Statistics.# of Delays.Carrier, Statistics.# of Delays.Late Aircraft, Statistics.# of Delays.National Aviation System, Statistics.# of Delays.Security, Statistics.# of Delays.Weather, Statistics.Carriers.Names, Statistics.Carriers.Total, Statistics.Flights.Cancelled, Statistics.Flights.Delayed, Statistics.Flights.Diverted, Statistics.Flights.On Time, Statistics.Flights.Total, Statistics.Minutes Delayed.Carrier, Statistics.Minutes Delayed.Late Aircraft, Statistics.Minutes Delayed.National Aviation System, Statistics.Minutes Delayed.Security, Statistics.Minutes Delayed.Total, Statistics.Minutes Delayed.Weather]
# Index: []
#
# [0 rows x 24 columns]

# %%
new_df = pd.read_csv("cars.csv")

# %%
new_df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
new_df.drop_duplicates()
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 5                 All-wheel drive
# ...

# %%
new_df.index
# Out:
# RangeIndex(start=0, stop=5076, step=1)

# %%
new_df.drop_duplicates(inplace=True)

# %%
new_df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 5                 All-wheel drive
# ...

# %%
new_df.describe()
# Out:
#        Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# count        5058.000000        5058.000000       5058.000000
# mean          145.679518         127.803480        143.850336
# std            62.195040          77.332826         79.956083
# min             1.000000           2.000000          1.000000
# 25%           104.000000          60.000000         62.000000
# 50%           152.000000         128.000000        158.000000
# 75%           193.000000         198.000000        219.000000
# max           255.000000         255.000000        254.000000
#
#        Engine Information.Number of Forward Gears  Fuel Information.City mpg  \
# count                                 5058.000000                5058.000000
# mean                                     5.519375                  17.275405
# std                                      0.845442                   4.483648
# min                                      4.000000                   8.000000
# ...

# %%
new_df.mean()
# Out:
# /tmp/ipykernel_4441/3764789720.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df.mean()
# Dimensions.Height                                   145.679518
# Dimensions.Length                                   127.803480
# Dimensions.Width                                    143.850336
# Engine Information.Hybrid                             1.000000
# Engine Information.Number of Forward Gears            5.519375
# Fuel Information.City mpg                            17.275405
# Fuel Information.Highway mpg                         24.127521
# Identification.Year                                2010.868525
# Engine Information.Engine Statistics.Horsepower     270.559312
# Engine Information.Engine Statistics.Torque         272.682483
# dtype: float64

# %%
new_df.isnull()
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                 False              False             False
# 1                 False              False             False
# 2                 False              False             False
# 3                 False              False             False
# 5                 False              False             False
# ...                 ...                ...               ...
# 5071              False              False             False
# 5072              False              False             False
# 5073              False              False             False
# 5074              False              False             False
# 5075              False              False             False
#
#       Engine Information.Driveline  Engine Information.Engine Type  \
# 0                            False                           False
# 1                            False                           False
# ...

# %%
new_df.isnull().sum()
# Out:
# Dimensions.Height                                  0
# Dimensions.Length                                  0
# Dimensions.Width                                   0
# Engine Information.Driveline                       0
# Engine Information.Engine Type                     0
# Engine Information.Hybrid                          0
# Engine Information.Number of Forward Gears         0
# Engine Information.Transmission                    0
# Fuel Information.City mpg                          0
# Fuel Information.Fuel Type                         0
# Fuel Information.Highway mpg                       0
# Identification.Classification                      0
# Identification.ID                                  0
# Identification.Make                                0
# Identification.Model Year                          0
# Identification.Year                                0
# Engine Information.Engine Statistics.Horsepower    0
# Engine Information.Engine Statistics.Torque        0
# ...

# %%
new_df.fillna(1)
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 5                 All-wheel drive
# ...

# %%
for col in new_df:
    print(col)
# Out:
# Dimensions.Height
# Dimensions.Length
# Dimensions.Width
# Engine Information.Driveline
# Engine Information.Engine Type
# Engine Information.Hybrid
# Engine Information.Number of Forward Gears
# Engine Information.Transmission
# Fuel Information.City mpg
# Fuel Information.Fuel Type
# Fuel Information.Highway mpg
# Identification.Classification
# Identification.ID
# Identification.Make
# Identification.Model Year
# Identification.Year
# Engine Information.Engine Statistics.Horsepower
# Engine Information.Engine Statistics.Torque

# %%
new_df["Dimensions.Height"]
# Out:
# 0       140
# 1       140
# 2       140
# 3       140
# 5        91
#        ...
# 5071     13
# 5072    141
# 5073    160
# 5074    200
# 5075    200
# Name: Dimensions.Height, Length: 5058, dtype: int64

# %%
new_df["Identification.ID"]
# Out:
# 0                                2009 Audi A3 3.2
# 1                           2009 Audi A3 2.0 T AT
# 2                              2009 Audi A3 2.0 T
# 3                      2009 Audi A3 2.0 T Quattro
# 5                                2009 Audi A5 3.2
#                           ...
# 5071                        2012 Honda Pilot EX-L
# 5072     2012 Lamborghini Gallardo Coupe LP 560-4
# 5073    2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074                          2012 BMW 740i Sedan
# 5075                         2012 BMW 740Li Sedan
# Name: Identification.ID, Length: 5058, dtype: object

# %%
new_df.to_csv("exported_class.csv")

# %%
new_df.to_json("exported_class.json")

# %%
import matplotlib.pyplot as plt

# %%
new_df.plot(kind="scatter",x="Dimensions.Height",y="Dimensions.Length",title="cars")
# Out:
# <AxesSubplot:title={'center':'cars'}, xlabel='Dimensions.Height', ylabel='Dimensions.Length'>

# %%
new_df.plot(kind="bar",x="Dimensions.Height",y="Dimensions.Length",title="cars")
# Out:
# <AxesSubplot:title={'center':'cars'}, xlabel='Dimensions.Height'>

# %%
new_df.plot(kind="bar",x="Fuel Information.City mpg",y="Fuel Information.Highway mpg",title="cars")
# Out:
# <AxesSubplot:title={'center':'cars'}, xlabel='Fuel Information.City mpg'>

# %%
df = pd.DataFrame([10,20,30,50,60])

# %%
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  50
# 4  60

# %%
df = pd.DataFrame([[10,20],[30,50],[10,30]],index=["First","Second","Third"])

# %%
df
# Out:
#          0   1
# First   10  20
# Second  30  50
# Third   10  30

# %%
new_df["Identification.Make"]
# Out:
# 0              Audi
# 1              Audi
# 2              Audi
# 3              Audi
# 5              Audi
#            ...
# 5071          Honda
# 5072    Lamborghini
# 5073    Lamborghini
# 5074            BMW
# 5075            BMW
# Name: Identification.Make, Length: 5058, dtype: object

# %%
pd.DataFrame(new_df["Identification.Make"])
# Out:
#      Identification.Make
# 0                   Audi
# 1                   Audi
# 2                   Audi
# 3                   Audi
# 5                   Audi
# ...                  ...
# 5071               Honda
# 5072         Lamborghini
# 5073         Lamborghini
# 5074                 BMW
# 5075                 BMW
#
# [5058 rows x 1 columns]

# %%
pd.DataFrame({"Col1":[1,2,3,4],"Col2":[3,4,5,5]})
# Out:
#    Col1  Col2
# 0     1     3
# 1     2     4
# 2     3     5
# 3     4     5

# %%
pd.DataFrame({"Identification.Make":new_df["Identification.Make"],"Identification.ID":new_df["Identification.ID"]})
# Out:
#      Identification.Make                          Identification.ID
# 0                   Audi                           2009 Audi A3 3.2
# 1                   Audi                      2009 Audi A3 2.0 T AT
# 2                   Audi                         2009 Audi A3 2.0 T
# 3                   Audi                 2009 Audi A3 2.0 T Quattro
# 5                   Audi                           2009 Audi A5 3.2
# ...                  ...                                        ...
# 5071               Honda                      2012 Honda Pilot EX-L
# 5072         Lamborghini   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073         Lamborghini  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074                 BMW                        2012 BMW 740i Sedan
# 5075                 BMW                       2012 BMW 740Li Sedan
#
# [5058 rows x 2 columns]

# %%
cov_df = pd.read_csv("covid.csv")

# %%
cov_df
# Out:
#        Date.Day  Date.Month  Date.Year  Data.Cases  Data.Deaths  \
# 0            31          12       2019           0            0
# 1            31          12       2019           0            0
# 2            31          12       2019           0            0
# 3            31          12       2019           0            0
# 4            31          12       2019           0            0
# ...         ...         ...        ...         ...          ...
# 53624        10          12       2020         202           16
# 53625        11          12       2020          63           10
# 53626        12          12       2020         113           11
# 53627        13          12       2020         298            9
# 53628        14          12       2020         746            6
#
#       Location.Country Location.Code  Data.Population Location.Continent  \
# 0          Afghanistan           AFG         38041757               Asia
# ...

# %%
cov_df.plot(kind="scatter",x="Data.Deaths",y="Date.Day",title="COVID")
# Out:
# <AxesSubplot:title={'center':'COVID'}, xlabel='Data.Deaths', ylabel='Date.Day'>

# %%
cov_df.plot(kind="scatter",x="Date.Day",y="Data.Deaths",title="COVID")
# Out:
# <AxesSubplot:title={'center':'COVID'}, xlabel='Date.Day', ylabel='Data.Deaths'>

# %%
cov_df.plot(kind="bar",x="Date.Day",y="Data.Deaths",title="COVID")
# Out:
# <AxesSubplot:title={'center':'COVID'}, xlabel='Date.Day'>

# %%
cov_df.plot(kind="bar", x="Location.Code", y="Data.Cases", title="COVID")
# Out:
# <AxesSubplot:title={'center':'COVID'}, xlabel='Location.Code'>

# %%
import seaborn as sb

# %%
sb.displot(data=cov_df, x="Data.Deaths", kde=True)

# %%
sb.displot(data=cov_df, x="Date.Day", kde=True)

# %%
sb.displot(data=cov_df, x="Date.Month", kde=True)

# %%
import pandas as pd

# %%
pd.options.plotting.backend="plotly"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7709/2004557154.py in <module>
# ----> 1 pd.options.plotting.backend="plotly"
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in __setattr__(self, key, val)
#     204         # can you can't overwrite subtrees
#     205         if key in self.d and not isinstance(self.d[key], dict):
# --> 206             _set_option(prefix, val)
#     207         else:
#     208             raise OptionError("You can only set the value of existing options")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     138         o = _get_registered_option(key)
#     139         if o and o.validator:
# --> 140             o.validator(v)
#     141
#     142         # walk the nested dict
#
# ...

# %%
new_df = pd.read_csv("covid.csv")

# %%
sb.histplot(new_df, x="Identification.ID", hue="Identification.Make", element="poly")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7709/1022866476.py in <module>
# ----> 1 sb.histplot(new_df, x="Identification.ID", hue="Identification.Make", element="poly")
#
# NameError: name 'sb' is not defined

# %%
# !pip3 install plotly
# Out:
# ...
#      |████████████████████████████████| 28.8 MB 267 kB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
import plotly as pl

# %%
import seaborn as sb

# %%
#pd.options.plotting.backend="plotly"

# %%
new_df = pd.read_csv("covid.csv")

# %%
sb.histplot(new_df, x="Location.Code", hue="Data.Cases", element="poly", discrete=False)
# Out:
# <AxesSubplot:xlabel='Location.Code', ylabel='Count'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...
